# %%
import pandas as pd
import numpy as np
import re
import statistics as stat

# %% [markdown]
# ### Data Cleaning

# %%
df = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv', low_memory = False, encoding = 'iso-8859-1')

# Rename Column Headers
df.rename(columns={'PMID/PMCID': 'pid', 
                   'Publisher': 'pub', 
                   'Journal title': 'j_title', 
                   'Article title':'a_title', 
                   'COST (£) charged to Wellcome (inc VAT when charged)': 'cost'}, 
          inplace=True)

# Common Text Mistakes
df.j_title = df.j_title.str.strip() # Remove whitespaces in journal titles
df.j_title = df.j_title.str.lower() # convert all to uppercase
df.j_title = df.j_title.str.replace(':','')
df.j_title = df.j_title.str.replace('&', 'and')
df.j_title = df.j_title.str.replace(',', '')
df.cost = df.cost.str.strip('$')
df.cost = df.cost.str.strip('£').astype(float)
df = df[df.cost < 9000.00]

# Spelling mistakes
df['j_title'] = df['j_title'].str.replace('antimicobial','antimicrobial')
df['j_title'] = df['j_title'].str.replace('agfents','agents')
df['j_title'] = df['j_title'].str.replace('angewande','angewandte')
df['j_title'] = df['j_title'].str.replace('behaviour','behavior')  
df['j_title'] = df['j_title'].str.replace('ophthalmology','opthalmology')  
df['j_title'] = df['j_title'].str.replace('jnl','journal') 
df['j_title'] = df['j_title'].str.replace('of','') 
df['j_title'] = df['j_title'].str.replace('.','') 
df['j_title'] = df['j_title'].str.replace('neuropathol','neuropathologica') 
df['j_title'] = df['j_title'].str.replace('neuropathologicaogica','neuropathologica') 
df['j_title'] = df['j_title'].str.replace('biinformatics','bionformatics') 
df['j_title'] = df['j_title'].str.replace('journals','journal') 
df['j_title'] = df['j_title'].str.replace('eur j immunol','european journal immunology') 
df['j_title'] = df['j_title'].str.replace('european child and adolescent psychiatty','european child and adolescent psychiatry') 
df['j_title'] = df['j_title'].str.replace('genetic epidemology','genetic epidemiology') 
df['j_title'] = df['j_title'].str.replace('haematologica/the haematology journal','haematologica') 
df['j_title'] = df['j_title'].str.replace('heptology','hepatology')
df['j_title'] = df['j_title'].str.replace('embo journal','embo') 
df['j_title'] = df['j_title'].str.replace('embo reports','embo') 
df['j_title'] = df['j_title'].str.replace('embo molecular medicine','embo') 
df['j_title'] = df['j_title'].str.replace('proceddings','proceedings') 
df['j_title'] = df['j_title'].str.replace('plosone','plos one') 
df['j_title'] = df['j_title'].str.replace('plos  one','plos one') 
df['j_title'] = df['j_title'].str.replace('proc natl acad sci u s a','the national academy sciences') 
df['j_title'] = df['j_title'].str.partition('part')
df['j_title'] = df['j_title'].str.partition('section')
df['j_title'] = df['j_title'].str.partition('online')
df['j_title'] = df['j_title'].str.replace('embo molecular medicine','embo')

# Combine similar journals
df['j_title'].loc[df['j_title'].str.contains('med chem')] = 'journal  medicinal chemistry'
df['j_title'].loc[df['j_title'].str.contains('british journal')] = 'british journal  the history  science'
df['j_title'].loc[df['j_title'].str.contains('clinical nutrition')] = 'american journal for clinical nutrition'
df['j_title'].loc[df['j_title'].str.contains('molecular basis  disease')] = 'biochimica et biophysica acta - molecular basis  disease'
# Out:
# C:\Users\edcha\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df.j_title.unique()
# Out:
# array(['psychological medicine', 'biomacromolecules',
#        'journal  medicinal chemistry', 'j org chem',
#        'journal  proteome research', 'mol pharm', 'acs chemical biology',
#        'journal  chemical information and modeling', 'biochemistry',
#        'gastroenterology', 'journal  biological chemistry',
#        'journal  immunology', 'acs chemical neuroscience', 'acs nano',
#        'american chemical society', 'analytical chemistry',
#        'bioconjugate chemistry', 'journal  the american chemical society',
#        'chest', 'journal  neurophysiology', 'journal  physiology',
#        'the journal  neurophysiology', 'american journal  psychiatry',
#        'americal journal  psychiatry', 'behavioral neuroscience',
#        'emotion', 'health psychology', 'journal  abnormal psychology',
#        'journal  consulting and clinical psychology',
#        'journal  experimental psychology  animal behavior process',
#        'journal  experimental psychology human perception and performance',
#        'journal  family psychology', 'psychological assessment',
#        'psychological review',
#        'psychological trauma theory research practice and policy',
#        'american journal  public health', 'j biol chem',
#        'the journal  biological chemistry', 'american journal  pathology',
#        'antimicrobial agents and chemotherapy',
#        'clinical and vaccine immunology', 'eukaryotic cell',
#        'infection and immunity', 'journal  bacteriology',
#        'journal  virology', 'mbio', 'molecular and cellular biology',
#        'journal  clinical microbiology', 'american society for nutrition',
#        'blood', 'blood journal 2012',
#        'the american journal  human genetics',
#        'jounral  clinical microbiology',
#        'speech language and hearing research', 'biological chemistry',
#        'biologicial chemistry', 'j biol chemistry',
#        'mcp (molecular and cellular proteomics)',
#        'molecular and cellular proteomics',
#        'journal biological chemistry', 'journal  biol chem',
#        'journal  vision', 'current topics in medicinal chemistry',
#        'current analytical chemistry',
#        'evidence ethos and experiment the anthropology and history  medical research in africa',
#        'biochem journal', 'molecular cell',
#        'arthritis research and therapy', 'biomed central',
#        'bmc  public health', 'bmc biology', 'bmc genetics',
#        'bmc genome biology', 'bmc genomics',
#        'bmc health services research', 'bmc medical genetics',
#        'bmc medicine', 'bmc microbiology', 'bmc molecular biology',
#        'bmc neurology', 'bmc neuroscience', 'bmc psychiatry',
#        'bmc public health', 'bmc research notes',
#        'bmc veterinary research', 'bms genomics', 'clinical proteomics',
#        'evodevo', 'genome biology', 'genome medicine',
#        'international journal for equity in health',
#        'international journal  behavioral nutrition and physical activity',
#        'international journal  health geographics',
#        'journal  cheminformatics', 'journal  neuroinflammation',
#        'lipids in health and disease', 'malaria journal',
#        'molecular brain', 'molecular pain', 'nutrition journal',
#        'orphanet journal  rare diseases', 'parasites and vectors',
#        'public health', 'respiratory research', 'virology journal',
#        'bmc infectious diseases', 'hum resour health', 'implement sci',
#        'parasit vectors', 'aids research and therapy', 'bmc pediatrics',
#        'human resources for health', 'trials', 'veterinary research',
#        'biophysical journal', 'european journal  endocrinology',
#        'journal  endocrinology', 'journal  molecular endocrinology',
#        'reproduction(cambridge england)', 'cellular microbiology',
#        'bmc medical ethics', 'bmc medical imaging',
#        'cost effectiveness and resource allocation', 'bjophthalmol',
#        'bmj', 'bmj open', 'british journal  the history  science',
#        'british medical journal', 'frontline gastroenterology',
#        'journal  clinical pathology',
#        'journal  epidemiology and community health',
#        'journal  medical ethics', 'journal  medical genetics',
#        'journal  neurology neurosurgery and psychiatry',
#        'sexually transmitted infections', 'gut',
#        'archives  disease in childhood', 'bmj quality and safety',
#        'heart', 'medical humanities', 'thorax', 'sex transm infect',
#        'postgraduate medical journal', 'veterinary record',
#        'thorax an international journal for respiratory medicine',
#        'european journal  health law', 'journal  neuroscience',
#        'heart and circulatory physiology', 'j clin microbiol',
#        'international psychogeriatrics', 'parasitology',
#        'medical history', 'ageing and society',
#        'epidemiology and infection',
#        'international journal  law in context',
#        'journal  the international neuropsychological society',
#        'public health nutrition', 'pyschological medicine',
#        'urban history', 'visual neuroscience',
#        'american journal  human genetics', 'stem cell reports',
#        'journal  clinical endocrinology and metabolism', 'journal  virol',
#        'journal  the international aids society', 'genes and development',
#        'learning and memory', 'genome research', 'rna',
#        'journal  cell science', 'biology open', 'development',
#        'developmental cell', 'disease models and mechanisms',
#        'j cell sci', 'international reviews  immunology',
#        'journal  the international african institute', 'cell reports',
#        'american journal for clinical nutrition',
#        'cell press - cell reports', 'g3 genes genomes genetics',
#        'genetics', 'j immunol',
#        'proceedings  the national academy  sciences',
#        'the journal  immunology', 'journal  nutrition', 'pnas',
#        'neuroimage', 'academy  nutrition and dietetics',
#        'american journal  geriatric psychiatry',
#        'american journal  preventive medicine', 'analytical biochemistry',
#        'animal behavior', 'applied energy', 'asian journal  psychiatry',
#        'atherosclerosis',
#        'biochimica et biophysica acta - molecular basis  disease',
#        'behavior research and therapy', 'behavioral brain research',
#        'biochemical and biophysical research communications',
#        'biochemical pharmacology',
#        'biochimica et bioohysica acta - gene regulatory mechanisms',
#        'biochimica et biophysica acta (bba) - molecular cell research',
#        'biochimie', 'biological psychiatry', 'biological psychology',
#        'biomaterials', 'biosystems', 'bone', 'brain and cognition',
#        'brain and language', 'brain research', 'cancer letters', 'cell',
#        'cell calcium', 'cell host and microbe', 'cell journal',
#        'cell metabolism', 'cell stem cell', 'cellular signalling',
#        'chemsitry and biology', 'clinical neurology and neurosurgery',
#        'clinical radiology', 'cognition', 'cognitive development',
#        'consciousness and cognition', 'cortex', 'current biology',
#        'current opinion in neurobiology', 'current opinion microbiology',
#        'current opinions in neurobiology', 'development cell',
#        'developmental biology', 'developmental cognitive neuroscience',
#        'diagnostic microbiology and infectious disease', 'elsevier',
#        'endeavour', 'epilepsy research', 'european journal  cell biology',
#        'european journal  medical genetics',
#        'european neuropsychopharmacology', 'experimental eye research',
#        'experimental hematology', 'experimental neurology',
#        'experimental parasitology', 'febs letters', 'febs open bio',
#        'fertility and sterility', 'free radical and biology medicine',
#        'fungal biology', 'fungal ecology', 'gene', 'gene therapy',
#        'health and place', 'immnunobiology', 'immunity',
#        'immunology letters', 'infection genetics and evolution',
#        'int journal for parasitology', 'international health',
#        'international journal for parasitology',
#        'international journal  applied earth observation and geoinformation',
#        'international journal  biochemistry and cell biology',
#        'international journal  cardiology',
#        'international journal  parasitology', 'j mol biol',
#        'j steroid biochem mol biol', 'journal  affective disorders',
#        'journal  allergy and clinical immunology',
#        'journal  anthropological archaeology',
#        'journal  archaeological science',
#        'journal  behavior therapy and experimental psychiatry',
#        'journal  clinical epidemiology', 'journal  clinical virology',
#        'journal  cycstic fibrosis', 'journal  hepatology',
#        'journal  historical geography', 'journal  hospital infections',
#        'journal  infection',
#        'journal  mechanisms  ageing and development',
#        'journal  molecular biology', 'journal  neuroscience methods',
#        'journal  nutrition education and behavior', 'journal  proteomics',
#        'journal  structural biology',
#        'journal  the american academy  child and adolescent psychiatry',
#        'journal  the american college  cardiology',
#        'journal  the neurological sciences',
#        'journal  transport geography', 'journal  virological methods',
#        'lancet', 'lancet global health',
#        'learning and individual differences', 'matrix biology',
#        'maturitas', 'mechanisms  ageing and development',
#        'microbes and infection', 'microbes infect', 'mol bio',
#        'molecular and biochemical parasitology',
#        'molecular and cellular endocrinology', 'molecular biology',
#        'molecular genetics and metabolism', 'molecular immunology',
#        'molecular phylogenetics and evolution', 'n biotechnol',
#        'neurobiology  aging', 'neurobiology  disease',
#        'neurobiology  learning and memory',
#        'neurochemistry international', 'neuroimage clinical',
#        'neurolmage', 'neuromuscular disorders', 'neuron',
#        'neuropharmacology', 'neurophysiologia', 'neuropsychologia',
#        'neuroscience', 'neuroscience and behavioral reviews',
#        'neuroscience letters', 'nitric oxide', 'opthalmology',
#        'osteoarthritis and cartilage', 'pain',
#        'parkinsonism and related disorders', 'parsitology',
#        'personality and individual differences', 'preventive medicine',
#        'protein expr purif', 'protist',
#        'pulmonary pharmacology and therapeutics',
#        'research in veterinary science', 'schizophrenia research',
#        'seizure', 'seminars in oncology', 'social science and medicine',
#        'stem cell research', 'structure',
#        'studies in history and philosophy  science ',
#        'tetrahedron letters', 'the americal journal  human genetics',
#        'the international journal  biochemistry and cell biology',
#        'the journal  steroid biochemistry and molecular biology',
#        'the lancet', 'the lancet neurology', 'the vet journal',
#        'ticks and tick-borne diseases',
#        'transactions  the royal society  tropical medicine and hygiene',
#        'trends in cognitive science', 'trends in genetics',
#        'trends in microbiology', 'trends in molecular medicine',
#        'trends in neuroscience', 'trends in neurosciences',
#        'trends in parasitology', 'tuberculosis', 'vaccine',
#        'vascular pharmacology', 'veterinary microbiology',
#        'veterinary parasitology', 'virology', 'virus research',
#        'vision research', 'lancet infect dis', 'math biosci', 'curr biol',
#        'endocrinology', 'molecular endocrinology',
#        'european respiratory journal', 'faseb journal',
#        'journal  leukocyte biology', 'the faseb journal', 'haematologica',
#        'frontiers in auditory cognitive neuroscience',
#        'frontiers in behavioral neuroscience',
#        'frontiers in brain imaging methods',
#        'frontiers in cellular neuroscience',
#        'frontiers in cognitive science',
#        'frontiers in decision neuroscience',
#        'frontiers in developmental psychology',
#        'frontiers in electrophysiology', 'frontiers in endocrinology',
#        'frontiers in genetics', 'frontiers in human neuroscience',
#        'frontiers in immunological memory', 'frontiers in inflammation',
#        'frontiers in invertebrate physiology',
#        'frontiers in molecular neuroscience',
#        'frontiers in schizophrenia', 'frontiers in systems neuroscience',
#        'frontiers in integrative neuroscience',
#        'frontiers in perception science',
#        'frontiers in consciousness research', 'frontiers in immunology',
#        'frontiers in neural circuits', 'frontiers in neurorobotics',
#        'frontiers in t cell biology', 'future neurology',
#        'future virology', 'future microbiology',
#        'future medicinal chemistry',
#        'international journal  rheumatology', 'journal  allergy',
#        'journal  parasitology research',
#        'oxidative medicine and cellular longevity',
#        'methods in molecular biology', 'oncotarget',
#        'molecular membrane biology',
#        'expert reviews in anti-infective chemotherapy', 'nanotechnology',
#        'ijtld', 'international journal  tuberculosis  and lung disease',
#        'acta crystallographica ', 'acta crystallography d', 'acta d',
#        'acta f', 'j synchrotron radiat',
#        'journal  applied crystallography',
#        'physics in biology and medicine', 'journal  alzheimer disease',
#        'theranostics', 'j med internet research',
#        'american journal  medical genetics', 'genetic epidemiology',
#        'the journal  pathology', 'european journal  immunology',
#        'journal  depression and anxiety', 'journal  pathology',
#        'clinical and experimental allergy', 'embo', 'biopolymers',
#        'development science', 'journal  medical virology',
#        'molecular microbiology', 'population space and place', 'traffic',
#        'tropical medicine and international health',
#        'the journal  physiology', 'hepatology',
#        'bulletin  the history  medicine', 'national academy  sciences',
#        'journal  visualized experiments',
#        'journal  neurology and translational neuroscience',
#        'nephron physiology', 'neurodegenerative diseases',
#        'neuroepidemiology', 'neuropsychobiology', 'respiration',
#        'autophagy', 'cell adhesion and migration', 'cell cycle',
#        'channels', 'epigenetics', 'epigentics', 'rna biology',
#        'neurology', 'antioxidants and redox signaling',
#        'tissue engineering ', 'stem cells and development',
#        'international journal  molecular sciences', 'jerph', 'sensors',
#        'journal  cognitive neuroscience',
#        'journal  visualized experiements',
#        'journal  visulaized expermiments',
#        'pnas (proceedings  the national academy  sciences  the united states  america',
#        'proceedings  the national academy  sciences  usa',
#        'proceedings  the national academy  sciences  the united states  america',
#        'biosocieties', 'cell death and disease',
#        'cell death and differentiation', 'frontiers',
#        'journal  cerebral blood flow and metabolism',
#        'journal  investigative dermatology', 'mucosal immunology',
#        'nature communications', 'scientific reports',
#        'european journal  human genetics', 'leukemia',
#        'nature neuroscience', 'cell death differentiation',
#        'genetics in medicine', 'international journal  obesity',
#        'kidney international', 'nature scientific reports',
#        'neuropsychopharmacology', 'oncogene', 'sci rep',
#        'scientific reports-11-00861b', 'the embo',
#        'the journal  investigative dermatology',
#        'translational psychiatry', 'optics express',
#        'alcohol and alcoholism', 'american journal epidemiology',
#        'american journal  epidemiology', 'brain',
#        'briefings in bioinformatics', 'british medical bulletin',
#        'cerebral cortex', 'clinical infectious diseases',
#        'clinical infectious diseases ', 'european heart journal ',
#        'health policy planning', 'human molecular genetics',
#        'int j epidemiol', 'international joural  epidemiology',
#        'international journal  epidemiology',
#        'journal  antimicrobial chemotherapy',
#        'journal  infectious diseases',
#        'journal  the national cancer institute', 'nucleic acids research',
#        'public health ethics', 'rheumatology', 'schizophrenia bulletin',
#        'social cognitive and affective neuroscience',
#        'cardiovascular research', 'clinicla infectious disease',
#        'glycobiology', 'inyernational journal  epidemiology',
#        'journal  gerontology series a medical sciences',
#        'journal  public health', 'molecular biology and evolution',
#        'nicotine and tobaco research', 'social history  medicine',
#        'bioinformatics ', 'cerebral cortex print', 'human mol genetics ',
#        'age and ageing', 'bionformatics', 'bioinformatics', 'brain ',
#        'briefings in functional genomics', 'cerebral cortex ', 'database',
#        'european journal  public health',
#        'health promotion international', 'history workshop journal',
#        'human molecular genetics ', 'human reproduction',
#        'international immunology', 'medical law review',
#        'mol biol and evolution',
#        'nephrology dialysis and transplantation',
#        'nephrology dialysis transplantation', 'nucleic acid research',
#        'oxford journal', 'protein engineering design and selection (',
#        'qjm an international journal  medicine',
#        'the journal  infectious diseases', 'j infect dis',
#        'environment and planning a', 'plos computational biology',
#        'plos genetics', 'plos ntd', 'plos one', 'plos pathogens',
#        'pnas usa', 'proceedings  the national academy  sciences  the usa',
#        'the national academy sciences',
#        'journal  poverty and social justice', 'asn neuro',
#        'biochemical journal', 'biochemical society transactions',
#        'essays in biochemistry', 'the biochemical journal',
#        'biochem soc trans', 'bioscience reports',
#        'proceedings  the national academy  sciences (pnas)', 'biology',
#        'computational biology', 'neglected tropical disease', 'plos',
#        'plos  computational biology', 'plos 1', 'plos biology',
#        'plos medicine', 'plos medicine journal',
#        'plos negected tropical diseases',
#        'plos neglected tropical diseases', 'pntd',
#        'public library  science', 'public library  science one',
#        'public service review', 'j cardiovasc magn reson',
#        'britsh journal  psychiatry', 'biology letters', 'interface',
#        'journal  the royal society interface',
#        'philos trans r soc london b biol sci',
#        'philosophical transactions b', 'proceedings b',
#        'proceedings  royal society', 'proceedings  the royal society',
#        'proceedings  the royal society b biological sciences',
#        'chemical communication', 'chemical society reviews',
#        'dalton transactions',
#        'photochemical and photobiological sciences',
#        'organic and biomolecular chemistry', 'chronic illness',
#        'european journal  preventive cardiology',
#        'health an interdisciplinary journal for the social study  health illness and medicine',
#        'history  the human sciences',
#        'journal  histochemistry and cytochemistry', 'neuroscientist',
#        'psychological science', 'social studies  science',
#        'journal  psychopharmacology', 'reproductive sciences',
#        'journal  the royal society  medicine short reports',
#        'european history quarterly',
#        'international journal  financial research',
#        'journal  biomedical graphics and computing', 'health',
#        'american journal  tropical medicine and hygiene',
#        'endocrine related cancer', 'journal  general virology',
#        'journal  microbiology', 'microbiology', 'sgm open option',
#        'the journal  neuroscience', 'acta dermato venereologica',
#        'acta diabetologica', 'acta neuropathologica',
#        'advances in experimental medicine and biology',
#        'anal bioanal chem', 'biogerontology', 'biomedical microdevices',
#        'brain structure and function', 'brain topography',
#        'calcified tissue international', 'cell and tissue research',
#        'cellular and molecular cell sciences',
#        'cellular and molecular life sciences', 'chromosome research',
#        'cognitive processing', 'cognitive therapy and research',
#        'current atherosclerosis reports',
#        'current obstetrics and gynecology reports',
#        'development genes and evolution', 'diabetologia',
#        'european child and adolescent psychiatry',
#        'european journal  clinical pharmacology',
#        'european journal  epidemiology', 'european radiology',
#        'experimental brain research', 'hernia', 'immunogenetics',
#        'inflammation research',
#        'journal  autism and development disorders',
#        'journal  autism and developmental disorders',
#        'journal  bioethical inquiry', 'journal  biological physics',
#        'journal  computational neuroscience',
#        'journal  inherited metabolic', 'journal  molecular neuroscience',
#        'journal  neurology',
#        'journal  the association for research in otolaryngology',
#        'mammalian genome', 'metabolomics',
#        'molecular and cellular biochemistry', 'neurogenetics',
#        'neuroinformatics', 'neuromolecular medicine',
#        'osteoporosis international', 'pflugers archiv',
#        'pflugers archive', 'psychopharmacology',
#        'reproductive medicine and biology', 'seminars in immunopathology',
#        'social psychiatry and psychiatric epidemiology',
#        'social psychiatry and psychiatric epidemiol', 'springer',
#        'the journal  abnormal child psychology and psychiatry',
#        'tropical animal health and production', 'urolithiasis',
#        'aids behav', 'open choice', 'springer science + business media',
#        'journal  bioenergetics and biomembranes', 'childs nerv syst',
#        'age', 'biomolecular nmr assignments',
#        'journal  molecular medicine', 'journal  neural transmission',
#        'journal  the american society for mass spectrometry',
#        'azania archaeological research in africa', 'aids care',
#        'annals  science', 'canadian journal  african studies',
#        'child neuropsychology', 'english studies',
#        'european journal  english studies', 'journal  cultural economy',
#        'medical anthropology', 'science as culture', 'am j bioeth',
#        'ethn health', 'american journal  bioethics--neuroscience',
#        'south asian history and culture', 'the history  the family',
#        'journal  experimental nanoscience', 'journal  applied physiology',
#        'pediatrics', 'biol open', 'journal  clinical endocrinology',
#        'journal od clinical endocrinology',
#        'the journal  visualized experiments', 'bjp',
#        'philosophical transactions  the royal society  london series b biological sciences',
#        'rstb 20120145', 'cancer research', 'science-research',
#        'am j trop med hyg', 'developing world bioethics',
#        'international journal  developmental biology', 'acta physiol',
#        'addiction', 'aging cell',
#        'alimentrary pharmacology and therapeutics',
#        'american ethnologist', 'american journal  medical genetics ',
#        'angewandte chemie', 'annals  human genetics', 'annals  neurology',
#        'annals  the new york academy  sciences',
#        'arthritis and rheumatism', 'bioethics', 'birth defects research ',
#        'chembiochem', 'chemistry -  european journal',
#        'child psychology psychiatry', 'clinical genetics', 'cytoskeleton',
#        'development dynamics', 'developmental science',
#        'diabetic medicine', 'ecology and evolution', 'ecology letters',
#        'epilepsia', 'european journal  neuroscience', 'evolution',
#        'experimental physiology', 'febs j', 'febs journal',
#        'fems microbiology letters', 'genes brain behavior',
#        'genesis journal  genetics', 'glia', 'hippocampus',
#        'human brain mapping', 'human mutation',
#        'human mutation variation informatics and disease',
#        'immunological reviews', 'inflammatory bowel diseases',
#        'international journal  geriatric psychiatry',
#        'international journal  stroke',
#        'journal  bone and mineral research',
#        'journal  cellular biochemistry',
#        'journal  child psychology and psychiatry',
#        'journal  evolutionary biology', 'journal  neurochemistry',
#        'journal  neuroendocrinology',
#        'journal  the history  the behavioral sciences',
#        'journal  the royal statistical society series c (applied statistics)',
#        'magnetic resonance in medicine', 'movement disorders',
#        'muscle and nerve', 'neuropathologicaogy and applied neurobiology',
#        'nmr in biomedicine', 'parasite immunology',
#        'plant biotechnology journal', 'protein science',
#        'rapid communications in mass spectrometry',
#        'sociology  health and illness', 'stem cells', 'the febs journal',
#        'brt journal clinical pharmacology',
#        'child care health development', 'drug and alcohol review',
#        'evolutionary applications',
#        'molecular genetics and genomic medicine',
#        'maternal and child nutrition', 'evaluation in clinical practice',
#        'journal  cell physiology', 'journal  internal medicine',
#        'journal  sleep research', 'child care heath and development',
#        'dev world bioeth', 'european journal immunology',
#        'influenza other respi viruses', 'marten child nutr',
#        'trop med int health', 'clinical transcriptional science',
#        'immunology', 'acta opthalmologica',
#        'american journal  transplantation',
#        'angewandte chemie international edition',
#        'british jounal  pharmacology', 'centaurus',
#        'criminal behavior and mental health', 'depression and anxiety',
#        'dermatologic surgery', 'economic history review', 'hpb',
#        'international journal  experimental pathology',
#        'journal  comparative neurology',
#        'journal  evaluation in clinical practice', 'journal  microscopy',
#        'journal  orthopedic research', 'journal  viral hepatitis',
#        'obesity reviews', 'statistics in medicine', 'synapse',
#        'the european journal  neuroscience', 'zoonoses and public health',
#        'angew chems int ed', 'chemmedchem', 'protemics',
#        'journal  small animal practice', 'aids', 'aids journal',
#        'aids uk', 'jaids journal  acquired immune deficiency syndromes',
#        'journal  acquired immune deficiency syndroms (jaids)',
#        'journal  aids', 'circulation research', 'pediatr infect dis j',
#        'journal  acquired immune deficiency syndromes'], dtype=object)

# %%
# Top 5 Journals
journal_count = df.groupby('j_title').count()
top5journals = journal_count.sort_values(['a_title'], ascending = False)
top5 = top5journals.head(5).index.tolist()

# %%
def journal_stats(journal_list, dataframe):
    for journal in journal_list:
        partition = pd.DataFrame(dataframe[dataframe['j_title']==journal])
        partition.cost.fillna(partition.cost.mean(),inplace=True) # impute na values with mean of that journal        
        partition_mean = partition.cost.mean()
        partition_median = partition.cost.median()
        partition_std = partition.cost.std()
        partition_count = len(partition)
        partition_sum = partition.cost.sum()
        print('Stats for', journal.upper(), '\nTotal: \t\t£{:2.2f}\nMean: \t\t£{:2.2f},\nMedian: \t£{:2.2f},\nStd. Dev: \t£{:2.2f},\nArticle Count: \t{}\n'
              .format(partition_sum, partition_mean, partition_median, partition_std, partition_count))

# %%
journal_stats(top5, df)
# Out:
# Stats for PLOS ONE
# Total: 		£177912.97
# Mean: 		£931.48,
# Median: 	£893.43,
# Std. Dev: 	£197.58,
# Article Count: 	191
#
# Stats for JOURNAL  BIOLOGICAL CHEMISTRY
# Total: 		£74026.60
# Mean: 		£1423.59,
# Median: 	£1301.14,
# Std. Dev: 	£411.95,
# Article Count: 	52
#
# Stats for NEUROIMAGE
# Total: 		£64239.88
# Mean: 		£2215.17,
# Median: 	£2326.43,
# Std. Dev: 	£266.65,
# Article Count: 	29
#
# Stats for NUCLEIC ACIDS RESEARCH
# Total: 		£29874.00
# Mean: 		£1149.00,
# Median: 	£852.00,
# Std. Dev: 	£442.94,
# Article Count: 	26
#
# Stats for PLOS PATHOGENS
# Total: 		£34603.07
# Mean: 		£1572.87,
# Median: 	£1600.25,
# Std. Dev: 	£161.78,
# Article Count: 	22
